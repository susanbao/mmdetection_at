# %%
from mmdet.apis import init_detector, inference_detector
from mmdet.apis import DetInferencer
# models = DetInferencer.list_models('mmdet')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mmdet.apis import init_detector, inference_detector
#       2 from mmdet.apis import DetInferencer
#       3 # models = DetInferencer.list_models('mmdet')
#
# File /media/xinli/active/mmdetection_at/mmdet/__init__.py:2
#       1 # Copyright (c) OpenMMLab. All rights reserved.
# ----> 2 import mmcv
#       3 import mmengine
#       4 from mmengine.utils import digit_version
#
# ModuleNotFoundError: No module named 'mmcv'

# %%
inferencer = DetInferencer(model='deformable-detr-refine-twostage_r50_16xb2-50e_coco')
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v3.0/deformable_detr/deformable-detr-refine-twostage_r50_16xb2-50e_coco/deformable-detr-refine-twostage_r50_16xb2-50e_coco_20221021_184714-acc8a5ff.pth
# Downloading: "https://download.openmmlab.com/mmdetection/v3.0/deformable_detr/deformable-detr-refine-twostage_r50_16xb2-50e_coco/deformable-detr-refine-twostage_r50_16xb2-50e_coco_20221021_184714-acc8a5ff.pth" to /home/xinli/.cache/torch/hub/checkpoints/deformable-detr-refine-twostage_r50_16xb2-50e_coco_20221021_184714-acc8a5ff.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: data_preprocessor.mean, data_preprocessor.std
#
# ...

# %%
# !mim download mmdet --config deformable-detr-refine-twostage_r50_16xb2-50e_coco --dest ./checkpoints
# Out:
# processing deformable-detr-refine-twostage_r50_16xb2-50e_coco...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.9/242.9 MiB 24.1 MB/s eta 0:00:0000:0100:01
# Successfully downloaded deformable-detr-refine-twostage_r50_16xb2-50e_coco_20221021_184714-acc8a5ff.pth to /media/xinli/active/mmdetection_at/checkpoints
# Successfully dumped deformable-detr-refine-twostage_r50_16xb2-50e_coco.py to /media/xinli/active/mmdetection_at/checkpoints

# %%
checkpoint = './checkpoints/deformable-detr-refine-twostage_r50_16xb2-50e_coco_20221021_184714-acc8a5ff.pth'
config_path = './checkpoints/deformable-detr-refine-twostage_r50_16xb2-50e_coco.py'
inferencer = DetInferencer(model=config_path, weights=checkpoint)
# Out:
# Loads checkpoint by local backend from path: ./checkpoints/deformable-detr-refine-twostage_r50_16xb2-50e_coco_20221021_184714-acc8a5ff.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: data_preprocessor.mean, data_preprocessor.std
#
# 02/25 00:04:31 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# /media/xinli/active/mmengine_at/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '

# %%
inferencer('./demo/demo.jpg', out_dir='./output')

# %%
from PIL import Image
Image.open('./output/vis/demo.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
mmdet/models/detectors/base_detr.py

# %% [markdown]
# ### remove files

# %%
import os
path = "/media/sanbao/active/mmdetection_at/pro_data/detr/train/outputs/"

for num in range(118288,125676):
    file_path = path + str(num) + ".json"
    os.remove(file_path)
